# %%
from sklearn import tree
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

df =pd.read_csv("/content/sample_data/Tulip-dataset.csv")

df
# Out:
#              species  petal length  petal width  sepal length  sepal width
# 0        Tulip Tarda           4.7          1.4           7.0          3.2
# 1        Tulip Tarda           4.5          1.5           6.4          3.2
# 2        Tulip Tarda           4.9          1.5           6.9          3.1
# 3        Tulip Tarda           4.0          1.3           5.5          2.3
# 4        Tulip Tarda           4.6          1.5           6.5          2.8
# ..               ...           ...          ...           ...          ...
# 145  Tulip Acuminata           1.4          0.3           4.8          3.0
# 146  Tulip Acuminata           1.6          0.2           5.1          3.8
# 147  Tulip Acuminata           1.4          0.2           4.6          3.2
# 148  Tulip Acuminata           1.5          0.2           5.3          3.7
# 149  Tulip Acuminata           1.4          0.2           5.0          3.3
#
# [150 rows x 5 columns]

# %%
atribut = ["sepal length", "sepal width", "petal length", "petal width"]

# %%
data = df.loc[:, atribut]
target = df["species"]

# %%
df
# Out:
#              species  petal length  petal width  sepal length  sepal width
# 0        Tulip Tarda           4.7          1.4           7.0          3.2
# 1        Tulip Tarda           4.5          1.5           6.4          3.2
# 2        Tulip Tarda           4.9          1.5           6.9          3.1
# 3        Tulip Tarda           4.0          1.3           5.5          2.3
# 4        Tulip Tarda           4.6          1.5           6.5          2.8
# ..               ...           ...          ...           ...          ...
# 145  Tulip Acuminata           1.4          0.3           4.8          3.0
# 146  Tulip Acuminata           1.6          0.2           5.1          3.8
# 147  Tulip Acuminata           1.4          0.2           4.6          3.2
# 148  Tulip Acuminata           1.5          0.2           5.3          3.7
# 149  Tulip Acuminata           1.4          0.2           5.0          3.3
#
# [150 rows x 5 columns]

# %%
target
# Out:
# 0          Tulip Tarda
# 1          Tulip Tarda
# 2          Tulip Tarda
# 3          Tulip Tarda
# 4          Tulip Tarda
#             ...
# 145    Tulip Acuminata
# 146    Tulip Acuminata
# 147    Tulip Acuminata
# 148    Tulip Acuminata
# 149    Tulip Acuminata
# Name: species, Length: 150, dtype: object

# %%
dataTraining, dataTesting, targetTraining, targetTesting = train_test_split(data
    , target, test_size = 0.2)

# %%
modelKlasifikasi= tree.DecisionTreeClassifier(criterion='entropy')
modelKlasifikasi= modelKlasifikasi.fit(dataTraining, targetTraining)

# %%
plt.subplots(figsize=(20, 20))

tree.plot_tree(modelKlasifikasi, feature_names = atribut, class_names =
    modelKlasifikasi.classes_, filled = True, fontsize = 12)
# Out:
# [Text(0.4, 0.9, 'petal width <= 0.8\nentropy = 1.584\nsamples = 120\nvalue = [38, 41, 41]\nclass = Tulip Clusiana'),
#  Text(0.2, 0.7, 'entropy = 0.0\nsamples = 38\nvalue = [38, 0, 0]\nclass = Tulip Acuminata'),
#  Text(0.6, 0.7, 'petal width <= 1.65\nentropy = 1.0\nsamples = 82\nvalue = [0, 41, 41]\nclass = Tulip Clusiana'),
#  Text(0.4, 0.5, 'petal length <= 4.95\nentropy = 0.359\nsamples = 44\nvalue = [0, 3, 41]\nclass = Tulip Tarda'),
#  Text(0.2, 0.3, 'entropy = 0.0\nsamples = 40\nvalue = [0, 0, 40]\nclass = Tulip Tarda'),
#  Text(0.6, 0.3, 'petal width <= 1.55\nentropy = 0.811\nsamples = 4\nvalue = [0, 3, 1]\nclass = Tulip Clusiana'),
#  Text(0.4, 0.1, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]\nclass = Tulip Clusiana'),
#  Text(0.8, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Tulip Tarda'),
#  Text(0.8, 0.5, 'entropy = 0.0\nsamples = 38\nvalue = [0, 38, 0]\nclass = Tulip Clusiana')]
